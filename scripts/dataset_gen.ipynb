# %%
from sklearn.datasets import make_blobs
import pandas as pd
import numpy as np
from pandas.plotting._matplotlib import scatter_matrix

# %%
dimension = 3
samples = 1000
centers = 7

points, y = make_blobs(n_samples=samples, centers=centers, n_features=dimension)

with open("./1k/dataset_3_7.txt", "w") as file:
    for point in points:
        for value in range(dimension):
            if value == (dimension - 1):
                file.write(str(round(point[value], 4)))
            else:
                file.write(str(round(point[value], 4)) + ",")
        file.write("\n")
        
data = np.array(points)

# %%
df = pd.DataFrame(data, columns=['x_0','x_1','x_2'])
scatter_matrix(df, alpha=0.2, figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002250D57BA48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002250FDA1148>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002250FDD7F48>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002250FE140C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002250FE4C1C8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002250FE85248>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002250FEBC388>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002250FEF9F88>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002250FF01088>]],
#       dtype=object)
